# %% [markdown]
# A function is a block of code which only runs when it is called .
#
# you can pass data, knowns as parameters, into a function
#
# A function can return data as result

# %%
#syntax

def function_name(name,age):

  print(name)
  print(age)

  return name

  print(function_name('arifa taj',21))

# %%
#function with out argument
def function_name():

  a = int(input('enter the number'))
  b = int(input('enter the number'))

  return a+b

print(function_name())
# Out:
# enter the number21
# enter the number23
# 44

# %%
#fuction with argument
def function_name(a,b):

  a = int(input('enter the number'))
  b = int(input('enter the number'))

  return a+b
print(function_name(4,6))
# Out:
# enter the number12
# enter the number43
# 55

# %%
# function with argument
def function_name(a,b):

  a = int(input('enter the number'))
  b = int(input('enter the number'))

  return a+b

print(function_name(1,2))
# Out:
# enter the number12
# enter the number21
# 33

# %%
#4 # function with out arguments and without return type
def function_name():

  a = int(input('enter the number1 '))
  b = int(input('enter the number2 '))

  return a+b
  print(sum)

print(function_name())
# Out:
# enter the number110
# enter the number220
# 30

# %%
def function_name(a,b):

  sub = a-b

  return sub

print(function_name(1,9))
# Out:
# -8

# %%
def function_name(a,b):
  if a>b:
    sub = a-b
  else:
    sub = b-a

    return sub

print(function_name(1,9))
# Out:
# 8

# %%
#defult arguments and non defualt arguments

def sub(a,b=40):

  if a>b:
    sub = a-b

  else :
    sub = b-a
    return sub

print
# Out:
# 31

# %%
# Out:
# 21

# %%
# Out:
# 120

# %%
# Out:
#   File "<ipython-input-15-58129b246b82>", line 1
#     def sum1(a,b,c)
#                    ^
# SyntaxError: expected ':'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-dfd98fcff41e> in <cell line: 6>()
#       4   #return sum2
#       5
# ----> 6 print(sum2(50,60,53,56,87,12,54))
#
# NameError: name 'sum2' is not defined

# %%
# Out:
# rif tj
